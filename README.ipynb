# %% [markdown]
# # Modelling handover and base station behaviour
#
# ## Model explained
#
# ### Base stations
# ### Users
# ### Handovers
# ### Switching of BS
# ### Linear programming
# ## Project files:
#
# ### customwalk.py
#
# It demonstrates the mobility model for moving users in the coordinate system.

# %%
# %run customwalk.py

# %% [markdown]
# ### prefefined_walk.py
#
# Generates 1000 steps for 90 usesr and saves result to predefined_walk.csv

# %% [markdown]
# ### handover_cost_comparison.py
#
# Runs 3 simulation with 3 different handover_cost_weight values. Each simulation consists of 1000 predefined steps of 90 users. Displays the number of handovers in each scenario.
#
# ![handover_cost_comparison](handover_cost.png)

# %% [markdown]
# ### switching_cost_comparison.py
# Runs 3 simulations with 3 different switching_cost_weight values. Each simulation consists of 1000 predefined steps of 90 users. Displays the number of gBN swtiches in each scenario.
#
# ![switching_cost_comparison_result](switching_cost.png)
